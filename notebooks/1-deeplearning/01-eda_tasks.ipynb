# %% [markdown]
# # Load libraries
#
# *** Import the following libraries:
#
# - os
# - opencv
# - Image from Pillow
# - numpy as np
# - pandas as pd
# - matplotlib.pyplot as plt

# %%
import os
import cv2
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %% [markdown]
# # Images & OpenCV
#
# - Create a list of file names in the validation directory and
# - print randomly 16 images:

# %%
images = !find "/keras2production/fruits/Training/Banana" -type f -name "*.jpg"
number_of_images = 16
#type(images)
some_random_images = random.sample(images, number_of_images)

figure = plt.figure()

for i in range(number_of_images):
    figure.add_subplot(4, 8, i + 1);
    plt.axis("off")
    image = plt.imread(some_random_images[i])
    plt.imshow(image)

# %% [markdown]
# *** Plot the first image using opencv with the following steps:
#
# - read image from file path
# - get bgr
# - convert to rgb
# - show plot
